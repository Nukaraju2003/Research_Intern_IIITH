# %% [markdown]
# <a href="https://colab.research.google.com/github/Nukaraju2003/IASNLPIIITH/blob/main/IITHyderabad_Class_1_21_june_mornsession.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %%
name = "maitri"

# %%
print("Hello " + name)
# Out:
# Hello maitri

# %%
print("Hello " ,  name)
# Out:
# Hello  maitri

# %% [markdown]
# # String

# %%
name.upper()
# Out:
# 'MAITRI'

# %%
print(f"Hello {name.upper()}")
# Out:
# Hello MAITRI

# %%
f = open('/content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/a/a-drama-queens-pavlova.json', 'r')

# %%
import json

# %%
json.load(f)
# Out:
# {'directions': ['Preheat the oven to 450 degrees F (220 degrees C). You will be turning the temperature down to 300 degrees F (150 degrees C) when you put this in to bake. Line a 9 or 10 inch round glass dish with parchment paper.',
#   'Combine the egg whites and salt in a large bowl. Beat with an electric mixer, or stand mixer using a whisk attachment until able to form soft peaks. Sprinkle in the sugar 1 tablespoon at a time while continuing to whip to stiff peaks. Stir in the vanilla and vinegar, and fold in coconut if using. Spread evenly into the prepared glass dish, making sure to spread out to all of the edges.',
#   'Place the Pavlova into the oven, and immediately reduce the temperature to 300 degrees F (150 degrees C). Bake for 40 to 50 minutes, or until the top is crisp and a pale straw color. Leave in the oven, and turn off the heat. Let it stay in the oven until the oven has cooled completely.',
# ...

# %%
type(f)
# Out:
# _io.TextIOWrapper

# %%
from glob import glob

# %%
fnames = glob('/content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/**/*.json', recursive = True)

# %% [markdown]
# empty list, file path, json.load, append to empty list, output should be list of disctionaries

# %%
# file_contents = f.read()

# %%
from pathlib import Path

# %%
p =  Path('/content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes')

# %%
import os
from pathlib import Path

p =  Path('/content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes')

# Use os.walk to traverse the directory
for root, dirs, files in os.walk(p):
    for file in files:
        print(os.path.join(root, file))
# Out:
# /content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/z/zucchini-appetizer.json
# /content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/z/zucchini-and-onion-pancake.json
# /content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/z/zesty-zucchini-and-squash.json
# /content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/z/zucchini-bread-vi.json
# /content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/z/zucchini-noodles-with-eggplant-and-tomatoes.json
# /content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/z/zucchini-soup-i.json
# /content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/z/zucchini-cornbread-casserole.json
# /content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/y/yummy-vegan-pesto-classico.json
# ...

# %%
list_example = [1, 2, 3, "a", [1, 2.0]]

# %%
for example in list_example:
  print(example)
# Out:
# 1
# 2
# 3
# a
# [1, 2.0]

# %%
list_example.append(100)
print(list_example)
# Out:
# [1, 2, 3, 'a', [1, 2.0], 100]

# %% [markdown]
# # Step1 : get the list of json file names of the reipes

# %%
from glob import glob

# %%
fnames = glob('/content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/**/*.json', recursive = True)

# %%
print(fnames)
# Out:
# ['/content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/z/zucchini-appetizer.json', '/content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/z/zucchini-and-onion-pancake.json', '/content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/z/zesty-zucchini-and-squash.json', '/content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/z/zucchini-bread-vi.json', '/content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/z/zucchini-noodles-with-eggplant-and-tomatoes.json', '/content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/z/zucchini-soup-i.json', '/content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/z/zucchini-cornbread-casserole.json', '/content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/y/yummy-vegan-pesto-classic
# ...

# %%
type(fnames)
# Out:
# list

# %% [markdown]
# # Step2 : Make an empty list

# %%
empty_list = []

# %%
print(empty_list)
# Out:
# []

# %%
type(empty_list)
# Out:
# list

# %% [markdown]
# # Step Loop over all recipe file names

# %%
fnames = glob('/content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/**/*.json', recursive = True)
recipes = []
for fname in fnames:
  with open(fname, "r") as f:
    recipe = json.load(f)
    recipes.append(recipe)
len(recipes)
recipes
# Out:
# [{'directions': ['Preheat oven to 350 degrees F (175 degrees C).',
#    'In a mixing bowl, stir together the baking mix, vegetable oil, dried parsley, pepper, garlic, egg, Romano cheese, salt and zucchini. Pour the mixture into a lightly greased 8x12 inch pan.',
#    'Bake 20 minutes, or until golden brown. Cut into squares and serve.'],
#   'ingredients': ['1 cup baking mix',
#    '1/2 cup vegetable oil',
#    '2 tablespoons dried parsley',
#    '1 pinch ground black pepper',
#    '2 cloves garlic, chopped',
#    '1 egg',
#    '1/2 cup grated Romano cheese',
#    '1/4 teaspoon salt',
#    '3 cups sliced zucchini'],
#   'language': 'en-US',
#   'source': 'allrecipes.com',
#   'tags': [],
#   'title': 'Zucchini Appetizer',
#   'url': 'http://allrecipes.com/recipe/20523/zucchini-appetizer/'},
#  {'directions': ['Grate zucchini and onion into a medium bowl, and drain off excess juices. Stir in the oregano and salt and pepper to taste.',
# ...

# %%
# for recipe in fnames:
#   recipeopen = open(recipe, 'r')
#   json.load(recipeopen)
  # print(recipeopen)
  # print(recipe.open())

# %%
# type(f.read())

# %%
# import json

# # Open the file in read mode
# with open('/content/drive/MyDrive/My Projects/IASNLP/21Juneintrotoprogramming/Datasets/Recipes/index/a/a-drama-queens-pavlova.json', 'r') as f:
#     # Read the contents of the file as a string
#     file_contents = f.read()

# # Load the JSON data from the string
# data = json.loads(file_contents)

# # Now you can work with the loaded JSON data
# print(data)

# %%
# json.load(f)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-34-2768ca17dda6> in <cell line: 1>()
# ----> 1 json.load(f)
#
# /usr/lib/python3.10/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
# ...

# %%
recipes[0]
# Out:
# {'directions': ['Preheat oven to 350 degrees F (175 degrees C).',
#   'In a mixing bowl, stir together the baking mix, vegetable oil, dried parsley, pepper, garlic, egg, Romano cheese, salt and zucchini. Pour the mixture into a lightly greased 8x12 inch pan.',
#   'Bake 20 minutes, or until golden brown. Cut into squares and serve.'],
#  'ingredients': ['1 cup baking mix',
#   '1/2 cup vegetable oil',
#   '2 tablespoons dried parsley',
#   '1 pinch ground black pepper',
#   '2 cloves garlic, chopped',
#   '1 egg',
#   '1/2 cup grated Romano cheese',
#   '1/4 teaspoon salt',
#   '3 cups sliced zucchini'],
#  'language': 'en-US',
#  'source': 'allrecipes.com',
#  'tags': [],
#  'title': 'Zucchini Appetizer',
#  'url': 'http://allrecipes.com/recipe/20523/zucchini-appetizer/'}

# %%
# recipe['directions']
# sublist = [recipes[i] for i in range(10)]
# sublist
# len(sublist)

# temp = []
# for recipe in recipes:
#   # print(recipe['title'])
#   # if 'egg' in recipe['ingredients']:
#   #   print(recipe['title'])
#   temp.append(recipe['title'])
# print(temp)



for recipe in recipes:
  # if 'egg' in recipe['ingredients']:
  # print(recipe['title'])
  print(recipe['ingredients'])


list1 = ["egg", "apple", "orange"]
for i in range(len(list1)):
  # print(list1[i])
  if list1[i] == "egg":
    print(list1[i])
    break
# Out:
# egg

# %% [markdown]
# ```
# 1. Figure out the key for the recipe name
# 2. figure out how to get the recipe
# 3. Use alist comprehension to collect all the recipe names
# # This is formatted as code
# ```

# %%
recipe = recipes[10]

# %%
#Find out all all recipes which contain egg
